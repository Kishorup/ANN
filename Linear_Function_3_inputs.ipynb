# %% [markdown]
# <a href="https://colab.research.google.com/github/Kishorup/ANN/blob/main/Linear_Function_3_inputs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# Seed for reproducibility
np.random.seed(42)

# Ground truth function
def true_function(x1, x2, x3):
    return 2 * x1 + 3 * x2 - x3 + 5

# Generate dataset
X = np.random.rand(10, 3)
y_true = np.array([true_function(x[0], x[1], x[2]) for x in X])

# Print dataset
print("Dataset (x1, x2, x3, y):")
for i in range(10):
    print(f"{X[i][0]:.3f}\t{X[i][1]:.3f}\t{X[i][2]:.3f}\t{y_true[i]:.3f}")
# Out:
# Dataset (x1, x2, x3, y):
# 0.375	0.951	0.732	7.869
# 0.599	0.156	0.156	6.509
# 0.058	0.866	0.601	7.114
# 0.708	0.021	0.970	5.508
# 0.832	0.212	0.182	7.120
# 0.183	0.304	0.525	5.755
# 0.432	0.291	0.612	6.126
# 0.139	0.292	0.366	5.789
# 0.456	0.785	0.200	8.068
# 0.514	0.592	0.046	7.759

# %%
# Initialize weights and bias
w1, w2, w3 = np.random.randn(3)
b = np.random.randn()

# Learning rate and number of epochs
alpha = 0.01
epochs = 100

# %%
for epoch in range(1, epochs + 1):
    total_error = 0
    print(f"\nEpoch {epoch}: Weights => w1 = {w1:.4f}, w2 = {w2:.4f}, w3 = {w3:.4f}, bias = {b:.4f}")

    for i in range(len(X)):
        x1, x2, x3 = X[i]
        target = y_true[i]

        y_pred = w1 * x1 + w2 * x2 + w3 * x3 + b
        error = target - y_pred
        total_error += error ** 2

        # Weight updates
        w1 += alpha * error * x1
        w2 += alpha * error * x2
        w3 += alpha * error * x3
        b += alpha * error

        print(f"Sample {i}: x1={x1:.3f}, x2={x2:.3f}, x3={x3:.3f}, "
              f"target={target:.3f}, pred={y_pred:.3f}, error={error:.3f}")
        print(f"         Updated weights => w1={w1:.4f}, w2={w2:.4f}, w3={w3:.4f}, bias={b:.4f}")

    mse = total_error / len(X)
    print(f"Epoch {epoch} MSE: {mse:.6f}")

    # Optional: Stop early if error is very low
    if mse < 1e-6:
        print("\nStopping early due to very low error.")
        break
# Out:
# Epoch 1: Weights => w1 = -1.1510, w2 = 0.3757, w3 = -0.6006, bias = -0.2917
# Sample 0: x1=0.375, x2=0.951, x3=0.732, target=7.869, pred=-0.805, error=8.674
#          Updated weights => w1=-1.1185, w2=0.4582, w3=-0.5371, bias=-0.2049
# Sample 1: x1=0.599, x2=0.156, x3=0.156, target=6.509, pred=-0.887, error=7.396
#          Updated weights => w1=-1.0742, w2=0.4697, w3=-0.5256, bias=-0.1310
# Sample 2: x1=0.058, x2=0.866, x3=0.601, target=7.114, pred=-0.102, error=7.216
#          Updated weights => w1=-1.0700, w2=0.5322, w3=-0.4822, bias=-0.0588
# Sample 3: x1=0.708, x2=0.021, x3=0.970, target=5.508, pred=-1.273, error=6.781
#          Updated weights => w1=-1.0220, w2=0.5336, w3=-0.4165, bias=0.0090
# Sample 4: x1=0.832, x2=0.212, x3=0.182, target=7.120, pred=-0.804, error=7.924
#          Updated weights => w1=-0.9561, w2=0.5504, w3=-0.4020, bias=0.0882
# Sample 5: x1=0.183, x2=0.304, x3=0.525, target=5.755, pred=-0.131, error=5.885
#          Updated weights => w1=-0.9453, w2=0.5683, w3=-0.3712, bias=0.1471
# Sample 6: x1=0.432, x2=0.291, x3=0.612, target=6.126, pred=-0.323, error=6.449
#          Updated weights => w1=-0.9174, w2=0.5871, w3=-0.3317, bias=0.2116
# Sample 7: x1=0.139, x2=0.292, x3=0.366, target=5.789, pred=0.134, error=5.655
#          Updated weights => w1=-0.9095, w2=0.6036, w3=-0.3110, bias=0.2681
# Sample 8: x1=0.456, x2=0.785, x3=0.200, target=8.068, pred=0.265, error=7.803
#          Updated weights => w1=-0.8739, w2=0.6649, w3=-0.2954, bias=0.3462
# Sample 9: x1=0.514, x2=0.592, x3=0.046, target=7.759, pred=0.277, error=7.482
#          Updated weights => w1=-0.8355, w2=0.7092, w3=-0.2919, bias=0.4210
# Epoch 1 MSE: 51.587705
#
# Epoch 2: Weights => w1 = -0.8355, w2 = 0.7092, w3 = -0.2919, bias = 0.4210
# Sample 0: x1=0.375, x2=0.951, x3=0.732, target=7.869, pred=0.569, error=7.301
#          Updated weights => w1=-0.8081, w2=0.7786, w3=-0.2385, bias=0.4940
# Sample 1: x1=0.599, x2=0.156, x3=0.156, target=6.509, pred=0.094, error=6.415
#          Updated weights => w1=-0.7697, w2=0.7886, w3=-0.2285, bias=0.5581
# Sample 2: x1=0.058, x2=0.866, x3=0.601, target=7.114, pred=1.059, error=6.054
#          Updated weights => w1=-0.7662, w2=0.8411, w3=-0.1921, bias=0.6187
# Sample 3: x1=0.708, x2=0.021, x3=0.970, target=5.508, pred=-0.093, error=5.601
#          Updated weights => w1=-0.7265, w2=0.8422, w3=-0.1378, bias=0.6747
# Sample 4: x1=0.832, x2=0.212, x3=0.182, target=7.120, pred=0.224, error=6.896
#          Updated weights => w1=-0.6691, w2=0.8569, w3=-0.1252, bias=0.7436
# Sample 5: x1=0.183, x2=0.304, x3=0.525, target=5.755, pred=0.816, error=4.939
#          Updated weights => w1=-0.6601, w2=0.8719, w3=-0.0993, bias=0.7930
# Sample 6: x1=0.432, x2=0.291, x3=0.612, target=6.126, pred=0.701, error=5.425
#          Updated weights => w1=-0.6366, w2=0.8877, w3=-0.0661, bias=0.8473
# Sample 7: x1=0.139, x2=0.292, x3=0.366, target=5.789, pred=0.994, error=4.795
#          Updated weights => w1=-0.6299, w2=0.9017, w3=-0.0486, bias=0.8952
# Sample 8: x1=0.456, x2=0.785, x3=0.200, target=8.068, pred=1.306, error=6.762
#          Updated weights => w1=-0.5991, w2=0.9548, w3=-0.0351, bias=0.9629
# Sample 9: x1=0.514, x2=0.592, x3=0.046, target=7.759, pred=1.219, error=6.540
#          Updated weights => w1=-0.5655, w2=0.9936, w3=-0.0320, bias=1.0283
# Epoch 2 MSE: 37.534934
#
# Epoch 3: Weights => w1 = -0.5655, w2 = 0.9936, w3 = -0.0320, bias = 1.0283
# Sample 0: x1=0.375, x2=0.951, x3=0.732, target=7.869, pred=1.738, error=6.132
#          Updated weights => w1=-0.5425, w2=1.0519, w3=0.0129, bias=1.0896
# Sample 1: x1=0.599, x2=0.156, x3=0.156, target=6.509, pred=0.931, error=5.578
#          Updated weights => w1=-0.5091, w2=1.0606, w3=0.0216, bias=1.1454
# Sample 2: x1=0.058, x2=0.866, x3=0.601, target=7.114, pred=2.047, error=5.066
#          Updated weights => w1=-0.5062, w2=1.1044, w3=0.0520, bias=1.1960
# Sample 3: x1=0.708, x2=0.021, x3=0.970, target=5.508, pred=0.911, error=4.597
#          Updated weights => w1=-0.4736, w2=1.1054, w3=0.0966, bias=1.2420
# Sample 4: x1=0.832, x2=0.212, x3=0.182, target=7.120, pred=1.100, error=6.020
#          Updated weights => w1=-0.4235, w2=1.1182, w3=0.1076, bias=1.3022
# Sample 5: x1=0.183, x2=0.304, x3=0.525, target=5.755, pred=1.621, error=4.134
#          Updated weights => w1=-0.4159, w2=1.1307, w3=0.1293, bias=1.3435
# Sample 6: x1=0.432, x2=0.291, x3=0.612, target=6.126, pred=1.572, error=4.553
#          Updated weights => w1=-0.3963, w2=1.1440, w3=0.1571, bias=1.3891
# Sample 7: x1=0.139, x2=0.292, x3=0.366, target=5.789, pred=1.726, error=4.063
#          Updated weights => w1=-0.3906, w2=1.1559, w3=0.1720, bias=1.4297
# Sample 8: x1=0.456, x2=0.785, x3=0.200, target=8.068, pred=2.193, error=5.875
#          Updated weights => w1=-0.3638, w2=1.2020, w3=0.1837, bias=1.4884
# Sample 9: x1=0.514, x2=0.592, x3=0.046, target=7.759, pred=2.022, error=5.737
#          Updated weights => w1=-0.3343, w2=1.2360, w3=0.1864, bias=1.5458
# Epoch 3 MSE: 27.351653
#
# Epoch 4: Weights => w1 = -0.3343, w2 = 1.2360, w3 = 0.1864, bias = 1.5458
# Sample 0: x1=0.375, x2=0.951, x3=0.732, target=7.869, pred=2.732, error=5.137
#          Updated weights => w1=-0.3151, w2=1.2848, w3=0.2240, bias=1.5972
# Sample 1: x1=0.599, x2=0.156, x3=0.156, target=6.509, pred=1.644, error=4.865
#          Updated weights => w1=-0.2859, w2=1.2924, w3=0.2316, bias=1.6458
# Sample 2: x1=0.058, x2=0.866, x3=0.601, target=7.114, pred=2.888, error=4.226
#          Updated weights => w1=-0.2835, w2=1.3290, w3=0.2570, bias=1.6881
# Sample 3: x1=0.708, x2=0.021, x3=0.970, target=5.508, pred=1.764, error=3.744
#          Updated weights => w1=-0.2570, w2=1.3298, w3=0.2933, bias=1.7255
# Sample 4: x1=0.832, x2=0.212, x3=0.182, target=7.120, pred=1.847, error=5.273
#          Updated weights => w1=-0.2131, w2=1.3410, w3=0.3029, bias=1.7783
# Sample 5: x1=0.183, x2=0.304, x3=0.525, target=5.755, pred=2.306, error=3.449
#          Updated weights => w1=-0.2067, w2=1.3515, w3=0.3210, bias=1.8128
# Sample 6: x1=0.432, x2=0.291, x3=0.612, target=6.126, pred=2.313, error=3.812
#          Updated weights => w1=-0.1903, w2=1.3626, w3=0.3443, bias=1.8509
# Sample 7: x1=0.139, x2=0.292, x3=0.366, target=5.789, pred=2.349, error=3.441
#          Updated weights => w1=-0.1855, w2=1.3726, w3=0.3569, bias=1.8853
# Sample 8: x1=0.456, x2=0.785, x3=0.200, target=8.068, pred=2.950, error=5.118
#          Updated weights => w1=-0.1621, w2=1.4128, w3=0.3671, bias=1.9365
# Sample 9: x1=0.514, x2=0.592, x3=0.046, target=7.759, pred=2.707, error=5.052
#          Updated weights => w1=-0.1362, w2=1.4428, w3=0.3695, bias=1.9870
# Epoch 4 MSE: 19.972239
#
# Epoch 5: Weights => w1 = -0.1362, w2 = 1.4428, w3 = 0.3695, bias = 1.9870
# Sample 0: x1=0.375, x2=0.951, x3=0.732, target=7.869, pred=3.578, error=4.291
#          Updated weights => w1=-0.1201, w2=1.4835, w3=0.4009, bias=2.0299
# Sample 1: x1=0.599, x2=0.156, x3=0.156, target=6.509, pred=2.252, error=4.257
#          Updated weights => w1=-0.0946, w2=1.4902, w3=0.4075, bias=2.0725
# Sample 2: x1=0.058, x2=0.866, x3=0.601, target=7.114, pred=3.603, error=3.511
#          Updated weights => w1=-0.0926, w2=1.5206, w3=0.4286, bias=2.1076
# Sample 3: x1=0.708, x2=0.021, x3=0.970, target=5.508, pred=2.489, error=3.019
#          Updated weights => w1=-0.0712, w2=1.5212, w3=0.4579, bias=2.1378
# Sample 4: x1=0.832, x2=0.212, x3=0.182, target=7.120, pred=2.485, error=4.635
#          Updated weights => w1=-0.0326, w2=1.5311, w3=0.4663, bias=2.1841
# Sample 5: x1=0.183, x2=0.304, x3=0.525, target=5.755, pred=2.889, error=2.866
#          Updated weights => w1=-0.0273, w2=1.5398, w3=0.4814, bias=2.2128
# Sample 6: x1=0.432, x2=0.291, x3=0.612, target=6.126, pred=2.944, error=3.182
#          Updated weights => w1=-0.0136, w2=1.5491, w3=0.5009, bias=2.2446
# Sample 7: x1=0.139, x2=0.292, x3=0.366, target=5.789, pred=2.879, error=2.910
#          Updated weights => w1=-0.0095, w2=1.5576, w3=0.5115, bias=2.2737
# Sample 8: x1=0.456, x2=0.785, x3=0.200, target=8.068, pred=3.594, error=4.474
#          Updated weights => w1=0.0109, w2=1.5927, w3=0.5205, bias=2.3184
# Sample 9: x1=0.514, x2=0.592, x3=0.046, target=7.759, pred=3.292, error=4.468
#          Updated weights => w1=0.0338, w2=1.6191, w3=0.5225, bias=2.3631
# Epoch 5 MSE: 14.624452
#
# Epoch 6: Weights => w1 = 0.0338, w2 = 1.6191, w3 = 0.5225, bias = 2.3631
# Sample 0: x1=0.375, x2=0.951, x3=0.732, target=7.869, pred=4.298, error=3.572
#          Updated weights => w1=0.0472, w2=1.6531, w3=0.5487, bias=2.3988
# Sample 1: x1=0.599, x2=0.156, x3=0.156, target=6.509, pred=2.771, error=3.739
#          Updated weights => w1=0.0696, w2=1.6589, w3=0.5545, bias=2.4362
# Sample 2: x1=0.058, x2=0.866, x3=0.601, target=7.114, pred=4.211, error=2.903
#          Updated weights => w1=0.0713, w2=1.6841, w3=0.5720, bias=2.4652
# Sample 3: x1=0.708, x2=0.021, x3=0.970, target=5.508, pred=3.105, error=2.403
#          Updated weights => w1=0.0883, w2=1.6846, w3=0.5953, bias=2.4893
# Sample 4: x1=0.832, x2=0.212, x3=0.182, target=7.120, pred=3.029, error=4.091
#          Updated weights => w1=0.1224, w2=1.6933, w3=0.6027, bias=2.5302
# Sample 5: x1=0.183, x2=0.304, x3=0.525, target=5.755, pred=3.384, error=2.371
#          Updated weights => w1=0.1267, w2=1.7005, w3=0.6151, bias=2.5539
# Sample 6: x1=0.432, x2=0.291, x3=0.612, target=6.126, pred=3.480, error=2.645
#          Updated weights => w1=0.1381, w2=1.7082, w3=0.6313, bias=2.5804
# Sample 7: x1=0.139, x2=0.292, x3=0.366, target=5.789, pred=3.330, error=2.459
#          Updated weights => w1=0.1416, w2=1.7154, w3=0.6403, bias=2.6049
# Sample 8: x1=0.456, x2=0.785, x3=0.200, target=8.068, pred=4.144, error=3.924
#          Updated weights => w1=0.1595, w2=1.7462, w3=0.6482, bias=2.6442
# Sample 9: x1=0.514, x2=0.592, x3=0.046, target=7.759, pred=3.791, error=3.969
#          Updated weights => w1=0.1799, w2=1.7697, w3=0.6500, bias=2.6839
# Epoch 6 MSE: 10.748680
#
# Epoch 7: Weights => w1 = 0.1799, w2 = 1.7697, w3 = 0.6500, bias = 2.6839
# Sample 0: x1=0.375, x2=0.951, x3=0.732, target=7.869, pred=4.910, error=2.960
#          Updated weights => w1=0.1910, w2=1.7978, w3=0.6717, bias=2.7135
# Sample 1: x1=0.599, x2=0.156, x3=0.156, target=6.509, pred=3.213, error=3.296
#          Updated weights => w1=0.2107, w2=1.8030, w3=0.6768, bias=2.7464
# Sample 2: x1=0.058, x2=0.866, x3=0.601, target=7.114, pred=4.727, error=2.386
#          Updated weights => w1=0.2121, w2=1.8236, w3=0.6912, bias=2.7703
# Sample 3: x1=0.708, x2=0.021, x3=0.970, target=5.508, pred=3.628, error=1.880
#          Updated weights => w1=0.2254, w2=1.8240, w3=0.7094, bias=2.7891
# Sample 4: x1=0.832, x2=0.212, x3=0.182, target=7.120, pred=3.493, error=3.627
#          Updated weights => w1=0.2556, w2=1.8317, w3=0.7160, bias=2.8254
# Sample 5: x1=0.183, x2=0.304, x3=0.525, target=5.755, pred=3.805, error=1.950
#          Updated weights => w1=0.2592, w2=1.8377, w3=0.7262, bias=2.8449
# Sample 6: x1=0.432, x2=0.291, x3=0.612, target=6.126, pred=3.936, error=2.189
#          Updated weights => w1=0.2686, w2=1.8440, w3=0.7396, bias=2.8667
# Sample 7: x1=0.139, x2=0.292, x3=0.366, target=5.789, pred=3.714, error=2.075
#          Updated weights => w1=0.2715, w2=1.8501, w3=0.7472, bias=2.8875
# Sample 8: x1=0.456, x2=0.785, x3=0.200, target=8.068, pred=4.613, error=3.455
#          Updated weights => w1=0.2873, w2=1.8772, w3=0.7541, bias=2.9220
# Sample 9: x1=0.514, x2=0.592, x3=0.046, target=7.759, pred=4.217, error=3.542
#          Updated weights => w1=0.3055, w2=1.8982, w3=0.7558, bias=2.9575
# Epoch 7 MSE: 7.939399
#
# Epoch 8: Weights => w1 = 0.3055, w2 = 1.8982, w3 = 0.7558, bias = 2.9575
# Sample 0: x1=0.375, x2=0.951, x3=0.732, target=7.869, pred=5.430, error=2.439
#          Updated weights => w1=0.3146, w2=1.9214, w3=0.7736, bias=2.9819
# Sample 1: x1=0.599, x2=0.156, x3=0.156, target=6.509, pred=3.591, error=2.919
#          Updated weights => w1=0.3321, w2=1.9260, w3=0.7782, bias=3.0111
# Sample 2: x1=0.058, x2=0.866, x3=0.601, target=7.114, pred=5.166, error=1.947
#          Updated weights => w1=0.3332, w2=1.9428, w3=0.7899, bias=3.0305
# Sample 3: x1=0.708, x2=0.021, x3=0.970, target=5.508, pred=4.073, error=1.435
#          Updated weights => w1=0.3434, w2=1.9431, w3=0.8038, bias=3.0449
# Sample 4: x1=0.832, x2=0.212, x3=0.182, target=7.120, pred=3.889, error=3.231
#          Updated weights => w1=0.3703, w2=1.9500, w3=0.8097, bias=3.0772
# Sample 5: x1=0.183, x2=0.304, x3=0.525, target=5.755, pred=4.163, error=1.592
#          Updated weights => w1=0.3732, w2=1.9548, w3=0.8180, bias=3.0931
# Sample 6: x1=0.432, x2=0.291, x3=0.612, target=6.126, pred=4.324, error=1.802
#          Updated weights => w1=0.3810, w2=1.9601, w3=0.8290, bias=3.1111
# Sample 7: x1=0.139, x2=0.292, x3=0.366, target=5.789, pred=4.041, error=1.748
#          Updated weights => w1=0.3834, w2=1.9652, w3=0.8355, bias=3.1286
# Sample 8: x1=0.456, x2=0.785, x3=0.200, target=8.068, pred=5.013, error=3.055
#          Updated weights => w1=0.3973, w2=1.9892, w3=0.8416, bias=3.1591
# Sample 9: x1=0.514, x2=0.592, x3=0.046, target=7.759, pred=4.581, error=3.178
#          Updated weights => w1=0.4137, w2=2.0080, w3=0.8430, bias=3.1909
# Epoch 8 MSE: 5.902761
#
# Epoch 9: Weights => w1 = 0.4137, w2 = 2.0080, w3 = 0.8430, bias = 3.1909
# Sample 0: x1=0.375, x2=0.951, x3=0.732, target=7.869, pred=5.872, error=1.997
#          Updated weights => w1=0.4212, w2=2.0270, w3=0.8576, bias=3.2109
# Sample 1: x1=0.599, x2=0.156, x3=0.156, target=6.509, pred=3.913, error=2.596
#          Updated weights => w1=0.4367, w2=2.0310, w3=0.8617, bias=3.2369
# Sample 2: x1=0.058, x2=0.866, x3=0.601, target=7.114, pred=5.539, error=1.574
#          Updated weights => w1=0.4376, w2=2.0447, w3=0.8712, bias=3.2526
# Sample 3: x1=0.708, x2=0.021, x3=0.970, target=5.508, pred=4.450, error=1.058
#          Updated weights => w1=0.4451, w2=2.0449, w3=0.8814, bias=3.2632
# Sample 4: x1=0.832, x2=0.212, x3=0.182, target=7.120, pred=4.228, error=2.892
#          Updated weights => w1=0.4692, w2=2.0510, w3=0.8867, bias=3.2921
# Sample 5: x1=0.183, x2=0.304, x3=0.525, target=5.755, pred=4.467, error=1.287
#          Updated weights => w1=0.4716, w2=2.0549, w3=0.8934, bias=3.3050
# Sample 6: x1=0.432, x2=0.291, x3=0.612, target=6.126, pred=4.654, error=1.472
#          Updated weights => w1=0.4779, w2=2.0592, w3=0.9024, bias=3.3197
# Sample 7: x1=0.139, x2=0.292, x3=0.366, target=5.789, pred=4.319, error=1.470
#          Updated weights => w1=0.4800, w2=2.0635, w3=0.9078, bias=3.3344
# Sample 8: x1=0.456, x2=0.785, x3=0.200, target=8.068, pred=5.355, error=2.713
#          Updated weights => w1=0.4923, w2=2.0848, w3=0.9133, bias=3.3615
# Sample 9: x1=0.514, x2=0.592, x3=0.046, target=7.759, pred=4.892, error=2.867
#          Updated weights => w1=0.5071, w2=2.1018, w3=0.9146, bias=3.3902
# Epoch 9 MSE: 4.425846
#
# Epoch 10: Weights => w1 = 0.5071, w2 = 2.1018, w3 = 0.9146, bias = 3.3902
# Sample 0: x1=0.375, x2=0.951, x3=0.732, target=7.869, pred=6.248, error=1.621
#          Updated weights => w1=0.5132, w2=2.1172, w3=0.9265, bias=3.4064
# Sample 1: x1=0.599, x2=0.156, x3=0.156, target=6.509, pred=4.188, error=2.321
#          Updated weights => w1=0.5271, w2=2.1208, w3=0.9301, bias=3.4296
# Sample 2: x1=0.058, x2=0.866, x3=0.601, target=7.114, pred=5.856, error=1.257
#          Updated weights => w1=0.5278, w2=2.1317, w3=0.9376, bias=3.4422
# Sample 3: x1=0.708, x2=0.021, x3=0.970, target=5.508, pred=4.769, error=0.739
#          Updated weights => w1=0.5330, w2=2.1319, w3=0.9448, bias=3.4496
# Sample 4: x1=0.832, x2=0.212, x3=0.182, target=7.120, pred=4.518, error=2.602
#          Updated weights => w1=0.5547, w2=2.1374, w3=0.9495, bias=3.4756
# Sample 5: x1=0.183, x2=0.304, x3=0.525, target=5.755, pred=4.726, error=1.029
#          Updated weights => w1=0.5566, w2=2.1405, w3=0.9549, bias=3.4859
# Sample 6: x1=0.432, x2=0.291, x3=0.612, target=6.126, pred=4.934, error=1.192
#          Updated weights => w1=0.5617, w2=2.1440, w3=0.9622, bias=3.4978
# Sample 7: x1=0.139, x2=0.292, x3=0.366, target=5.789, pred=4.555, error=1.234
#          Updated weights => w1=0.5634, w2=2.1476, w3=0.9667, bias=3.5102
# Sample 8: x1=0.456, x2=0.785, x3=0.200, target=8.068, pred=5.646, error=2.422
#          Updated weights => w1=0.5745, w2=2.1666, w3=0.9716, bias=3.5344
# Sample 9: x1=0.514, x2=0.592, x3=0.046, target=7.759, pred=5.158, error=2.601
#          Updated weights => w1=0.5878, w2=2.1820, w3=0.9728, bias=3.5604
# Epoch 10 MSE: 3.354380
#
# Epoch 11: Weights => w1 = 0.5878, w2 = 2.1820, w3 = 0.9728, bias = 3.5604
# Sample 0: x1=0.375, x2=0.951, x3=0.732, target=7.869, pred=6.567, error=1.302
#          Updated weights => w1=0.5927, w2=2.1944, w3=0.9823, bias=3.5734
# Sample 1: x1=0.599, x2=0.156, x3=0.156, target=6.509, pred=4.424, error=2.086
#          Updated weights => w1=0.6052, w2=2.1977, w3=0.9856, bias=3.5943
# Sample 2: x1=0.058, x2=0.866, x3=0.601, target=7.114, pred=6.125, error=0.988
#          Updated weights => w1=0.6058, w2=2.2062, w3=0.9915, bias=3.6041
# Sample 3: x1=0.708, x2=0.021, x3=0.970, target=5.508, pred=5.040, error=0.468
#          Updated weights => w1=0.6091, w2=2.2063, w3=0.9960, bias=3.6088
# Sample 4: x1=0.832, x2=0.212, x3=0.182, target=7.120, pred=4.765, error=2.355
#          Updated weights => w1=0.6287, w2=2.2113, w3=1.0003, bias=3.6324
# Sample 5: x1=0.183, x2=0.304, x3=0.525, target=5.755, pred=4.945, error=0.809
#          Updated weights => w1=0.6302, w2=2.2138, w3=1.0046, bias=3.6405
# Sample 6: x1=0.432, x2=0.291, x3=0.612, target=6.126, pred=5.172, error=0.954
#          Updated weights => w1=0.6343, w2=2.2166, w3=1.0104, bias=3.6500
# Sample 7: x1=0.139, x2=0.292, x3=0.366, target=5.789, pred=4.756, error=1.033
#          Updated weights => w1=0.6357, w2=2.2196, w3=1.0142, bias=3.6603
# Sample 8: x1=0.456, x2=0.785, x3=0.200, target=8.068, pred=5.896, error=2.172
#          Updated weights => w1=0.6457, w2=2.2366, w3=1.0185, bias=3.6821
# Sample 9: x1=0.514, x2=0.592, x3=0.046, target=7.759, pred=5.386, error=2.373
#          Updated weights => w1=0.6579, w2=2.2507, w3=1.0196, bias=3.7058
# Epoch 11 MSE: 2.576589
#
# Epoch 12: Weights => w1 = 0.6579, w2 = 2.2507, w3 = 1.0196, bias = 3.7058
# Sample 0: x1=0.375, x2=0.951, x3=0.732, target=7.869, pred=6.838, error=1.031
#          Updated weights => w1=0.6617, w2=2.2605, w3=1.0272, bias=3.7161
# Sample 1: x1=0.599, x2=0.156, x3=0.156, target=6.509, pred=4.625, error=1.884
#          Updated weights => w1=0.6730, w2=2.2634, w3=1.0301, bias=3.7349
# Sample 2: x1=0.058, x2=0.866, x3=0.601, target=7.114, pred=6.354, error=0.760
#          Updated weights => w1=0.6734, w2=2.2700, w3=1.0347, bias=3.7425
# Sample 3: x1=0.708, x2=0.021, x3=0.970, target=5.508, pred=5.270, error=0.238
#          Updated weights => w1=0.6751, w2=2.2701, w3=1.0370, bias=3.7449
# Sample 4: x1=0.832, x2=0.212, x3=0.182, target=7.120, pred=4.977, error=2.143
#          Updated weights => w1=0.6930, w2=2.2746, w3=1.0409, bias=3.7663
# Sample 5: x1=0.183, x2=0.304, x3=0.525, target=5.755, pred=5.132, error=0.623
#          Updated weights => w1=0.6941, w2=2.2765, w3=1.0442, bias=3.7726
# Sample 6: x1=0.432, x2=0.291, x3=0.612, target=6.126, pred=5.374, error=0.751
#          Updated weights => w1=0.6973, w2=2.2787, w3=1.0488, bias=3.7801
# Sample 7: x1=0.139, x2=0.292, x3=0.366, target=5.789, pred=4.927, error=0.862
#          Updated weights => w1=0.6986, w2=2.2812, w3=1.0519, bias=3.7887
# Sample 8: x1=0.456, x2=0.785, x3=0.200, target=8.068, pred=6.108, error=1.960
#          Updated weights => w1=0.7075, w2=2.2966, w3=1.0558, bias=3.8083
# Sample 9: x1=0.514, x2=0.592, x3=0.046, target=7.759, pred=5.582, error=2.178
#          Updated weights => w1=0.7187, w2=2.3095, w3=1.0568, bias=3.8301
# Epoch 12 MSE: 2.011495
#
# Epoch 13: Weights => w1 = 0.7187, w2 = 2.3095, w3 = 1.0568, bias = 3.8301
# Sample 0: x1=0.375, x2=0.951, x3=0.732, target=7.869, pred=7.069, error=0.801
#          Updated weights => w1=0.7217, w2=2.3171, w3=1.0627, bias=3.8381
# Sample 1: x1=0.599, x2=0.156, x3=0.156, target=6.509, pred=4.797, error=1.712
#          Updated weights => w1=0.7319, w2=2.3198, w3=1.0654, bias=3.8552
# Sample 2: x1=0.058, x2=0.866, x3=0.601, target=7.114, pred=6.547, error=0.566
#          Updated weights => w1=0.7323, w2=2.3247, w3=1.0688, bias=3.8609
# Sample 3: x1=0.708, x2=0.021, x3=0.970, target=5.508, pred=5.464, error=0.044
#          Updated weights => w1=0.7326, w2=2.3247, w3=1.0692, bias=3.8613
# Sample 4: x1=0.832, x2=0.212, x3=0.182, target=7.120, pred=5.159, error=1.961
#          Updated weights => w1=0.7489, w2=2.3289, w3=1.0728, bias=3.8809
# Sample 5: x1=0.183, x2=0.304, x3=0.525, target=5.755, pred=5.290, error=0.465
#          Updated weights => w1=0.7498, w2=2.3303, w3=1.0752, bias=3.8856
# Sample 6: x1=0.432, x2=0.291, x3=0.612, target=6.126, pred=5.546, error=0.580
#          Updated weights => w1=0.7523, w2=2.3320, w3=1.0788, bias=3.8914
# Sample 7: x1=0.139, x2=0.292, x3=0.366, target=5.789, pred=5.073, error=0.716
#          Updated weights => w1=0.7533, w2=2.3341, w3=1.0814, bias=3.8985
# Sample 8: x1=0.456, x2=0.785, x3=0.200, target=8.068, pred=6.291, error=1.777
#          Updated weights => w1=0.7614, w2=2.3480, w3=1.0849, bias=3.9163
# Sample 9: x1=0.514, x2=0.592, x3=0.046, target=7.759, pred=5.749, error=2.010
#          Updated weights => w1=0.7717, w2=2.3599, w3=1.0859, bias=3.9364
# Epoch 13 MSE: 1.600436
#
# Epoch 14: Weights => w1 = 0.7717, w2 = 2.3599, w3 = 1.0859, bias = 3.9364
# Sample 0: x1=0.375, x2=0.951, x3=0.732, target=7.869, pred=7.264, error=0.605
#          Updated weights => w1=0.7740, w2=2.3657, w3=1.0903, bias=3.9425
# Sample 1: x1=0.599, x2=0.156, x3=0.156, target=6.509, pred=4.945, error=1.564
#          Updated weights => w1=0.7833, w2=2.3681, w3=1.0927, bias=3.9581
# Sample 2: x1=0.058, x2=0.866, x3=0.601, target=7.114, pred=6.712, error=0.402
#          Updated weights => w1=0.7836, w2=2.3716, w3=1.0952, bias=3.9621
# Sample 3: x1=0.708, x2=0.021, x3=0.970, target=5.508, pred=5.628, error=-0.120
#          Updated weights => w1=0.7827, w2=2.3716, w3=1.0940, bias=3.9609
# Sample 4: x1=0.832, x2=0.212, x3=0.182, target=7.120, pred=5.315, error=1.805
#          Updated weights => w1=0.7977, w2=2.3754, w3=1.0973, bias=3.9790
# Sample 5: x1=0.183, x2=0.304, x3=0.525, target=5.755, pred=5.424, error=0.331
#          Updated weights => w1=0.7983, w2=2.3764, w3=1.0990, bias=3.9823
# Sample 6: x1=0.432, x2=0.291, x3=0.612, target=6.126, pred=5.692, error=0.434
#          Updated weights => w1=0.8002, w2=2.3777, w3=1.1017, bias=3.9866
# Sample 7: x1=0.139, x2=0.292, x3=0.366, target=5.789, pred=5.196, error=0.593
#          Updated weights => w1=0.8010, w2=2.3794, w3=1.1038, bias=3.9925
# Sample 8: x1=0.456, x2=0.785, x3=0.200, target=8.068, pred=6.447, error=1.621
#          Updated weights => w1=0.8084, w2=2.3921, w3=1.1071, bias=4.0088
# Sample 9: x1=0.514, x2=0.592, x3=0.046, target=7.759, pred=5.893, error=1.866
#          Updated weights => w1=0.8180, w2=2.4032, w3=1.1079, bias=4.0274
# Epoch 14 MSE: 1.300918
#
# Epoch 15: Weights => w1 = 0.8180, w2 = 2.4032, w3 = 1.1079, bias = 4.0274
# Sample 0: x1=0.375, x2=0.951, x3=0.732, target=7.869, pred=7.430, error=0.440
#          Updated weights => w1=0.8197, w2=2.4074, w3=1.1112, bias=4.0318
# Sample 1: x1=0.599, x2=0.156, x3=0.156, target=6.509, pred=5.071, error=1.438
#          Updated weights => w1=0.8283, w2=2.4096, w3=1.1134, bias=4.0462
# Sample 2: x1=0.058, x2=0.866, x3=0.601, target=7.114, pred=6.851, error=0.263
#          Updated weights => w1=0.8284, w2=2.4119, w3=1.1150, bias=4.0488
# Sample 3: x1=0.708, x2=0.021, x3=0.970, target=5.508, pred=5.767, error=-0.259
#          Updated weights => w1=0.8266, w2=2.4118, w3=1.1125, bias=4.0462
# Sample 4: x1=0.832, x2=0.212, x3=0.182, target=7.120, pred=5.449, error=1.671
#          Updated weights => w1=0.8405, w2=2.4154, w3=1.1155, bias=4.0630
# Sample 5: x1=0.183, x2=0.304, x3=0.525, target=5.755, pred=5.537, error=0.217
#          Updated weights => w1=0.8409, w2=2.4161, w3=1.1167, bias=4.0651
# Sample 6: x1=0.432, x2=0.291, x3=0.612, target=6.126, pred=5.815, error=0.311
#          Updated weights => w1=0.8423, w2=2.4170, w3=1.1186, bias=4.0682
# Sample 7: x1=0.139, x2=0.292, x3=0.366, target=5.789, pred=5.302, error=0.487
#          Updated weights => w1=0.8430, w2=2.4184, w3=1.1203, bias=4.0731
# Sample 8: x1=0.456, x2=0.785, x3=0.200, target=8.068, pred=6.580, error=1.488
#          Updated weights => w1=0.8497, w2=2.4301, w3=1.1233, bias=4.0880
# Sample 9: x1=0.514, x2=0.592, x3=0.046, target=7.759, pred=6.017, error=1.743
#          Updated weights => w1=0.8587, w2=2.4404, w3=1.1241, bias=4.1054
# Epoch 15 MSE: 1.082165
#
# Epoch 16: Weights => w1 = 0.8587, w2 = 2.4404, w3 = 1.1241, bias = 4.1054
# Sample 0: x1=0.375, x2=0.951, x3=0.732, target=7.869, pred=7.570, error=0.299
#          Updated weights => w1=0.8598, w2=2.4432, w3=1.1263, bias=4.1084
# Sample 1: x1=0.599, x2=0.156, x3=0.156, target=6.509, pred=5.180, error=1.329
#          Updated weights => w1=0.8678, w2=2.4453, w3=1.1284, bias=4.1217
# Sample 2: x1=0.058, x2=0.866, x3=0.601, target=7.114, pred=6.968, error=0.145
#          Updated weights => w1=0.8679, w2=2.4466, w3=1.1293, bias=4.1231
# Sample 3: x1=0.708, x2=0.021, x3=0.970, target=5.508, pred=5.883, error=-0.375
#          Updated weights => w1=0.8652, w2=2.4465, w3=1.1256, bias=4.1194
# Sample 4: x1=0.832, x2=0.212, x3=0.182, target=7.120, pred=5.564, error=1.556
#          Updated weights => w1=0.8782, w2=2.4498, w3=1.1284, bias=4.1350
# Sample 5: x1=0.183, x2=0.304, x3=0.525, target=5.755, pred=5.634, error=0.121
#          Updated weights => w1=0.8784, w2=2.4502, w3=1.1291, bias=4.1362
# Sample 6: x1=0.432, x2=0.291, x3=0.612, target=6.126, pred=5.920, error=0.206
#          Updated weights => w1=0.8793, w2=2.4508, w3=1.1303, bias=4.1382
# Sample 7: x1=0.139, x2=0.292, x3=0.366, target=5.789, pred=5.391, error=0.398
#          Updated weights => w1=0.8798, w2=2.4519, w3=1.1318, bias=4.1422
# Sample 8: x1=0.456, x2=0.785, x3=0.200, target=8.068, pred=6.695, error=1.373
#          Updated weights => w1=0.8861, w2=2.4627, w3=1.1345, bias=4.1559
# Sample 9: x1=0.514, x2=0.592, x3=0.046, target=7.759, pred=6.123, error=1.636
#          Updated weights => w1=0.8945, w2=2.4724, w3=1.1353, bias=4.1723
# Epoch 16 MSE: 0.921886
#
# Epoch 17: Weights => w1 = 0.8945, w2 = 2.4724, w3 = 1.1353, bias = 4.1723
# Sample 0: x1=0.375, x2=0.951, x3=0.732, target=7.869, pred=7.689, error=0.180
#          Updated weights => w1=0.8952, w2=2.4741, w3=1.1366, bias=4.1741
# Sample 1: x1=0.599, x2=0.156, x3=0.156, target=6.509, pred=5.273, error=1.236
#          Updated weights => w1=0.9026, w2=2.4760, w3=1.1385, bias=4.1865
# Sample 2: x1=0.058, x2=0.866, x3=0.601, target=7.114, pred=7.068, error=0.046
#          Updated weights => w1=0.9026, w2=2.4764, w3=1.1388, bias=4.1869
# Sample 3: x1=0.708, x2=0.021, x3=0.970, target=5.508, pred=5.982, error=-0.474
#          Updated weights => w1=0.8992, w2=2.4763, w3=1.1342, bias=4.1822
# Sample 4: x1=0.832, x2=0.212, x3=0.182, target=7.120, pred=5.663, error=1.457
#          Updated weights => w1=0.9114, w2=2.4794, w3=1.1369, bias=4.1968
# Sample 5: x1=0.183, x2=0.304, x3=0.525, target=5.755, pred=5.715, error=0.040
#          Updated weights => w1=0.9115, w2=2.4796, w3=1.1371, bias=4.1972
# Sample 6: x1=0.432, x2=0.291, x3=0.612, target=6.126, pred=6.009, error=0.117
#          Updated weights => w1=0.9120, w2=2.4799, w3=1.1378, bias=4.1983
# Sample 7: x1=0.139, x2=0.292, x3=0.366, target=5.789, pred=5.467, error=0.322
#          Updated weights => w1=0.9124, w2=2.4808, w3=1.1390, bias=4.2016
# Sample 8: x1=0.456, x2=0.785, x3=0.200, target=8.068, pred=6.793, error=1.275
#          Updated weights => w1=0.9182, w2=2.4908, w3=1.1415, bias=4.2143
# Sample 9: x1=0.514, x2=0.592, x3=0.046, target=7.759, pred=6.215, error=1.544
#          Updated weights => w1=0.9262, w2=2.5000, w3=1.1422, bias=4.2297
# Epoch 17 MSE: 0.803941
#
# Epoch 18: Weights => w1 = 0.9262, w2 = 2.5000, w3 = 1.1422, bias = 4.2297
# Sample 0: x1=0.375, x2=0.951, x3=0.732, target=7.869, pred=7.790, error=0.080
#          Updated weights => w1=0.9265, w2=2.5008, w3=1.1428, bias=4.2305
# Sample 1: x1=0.599, x2=0.156, x3=0.156, target=6.509, pred=5.354, error=1.156
#          Updated weights => w1=0.9334, w2=2.5026, w3=1.1446, bias=4.2421
# Sample 2: x1=0.058, x2=0.866, x3=0.601, target=7.114, pred=7.152, error=-0.038
#          Updated weights => w1=0.9334, w2=2.5022, w3=1.1444, bias=4.2417
# Sample 3: x1=0.708, x2=0.021, x3=0.970, target=5.508, pred=6.064, error=-0.556
#          Updated weights => w1=0.9294, w2=2.5021, w3=1.1390, bias=4.2362
# Sample 4: x1=0.832, x2=0.212, x3=0.182, target=7.120, pred=5.748, error=1.372
#          Updated weights => w1=0.9408, w2=2.5050, w3=1.1415, bias=4.2499
# Sample 5: x1=0.183, x2=0.304, x3=0.525, target=5.755, pred=5.784, error=-0.029
#          Updated weights => w1=0.9408, w2=2.5049, w3=1.1414, bias=4.2496
# Sample 6: x1=0.432, x2=0.291, x3=0.612, target=6.126, pred=6.084, error=0.042
#          Updated weights => w1=0.9410, w2=2.5051, w3=1.1416, bias=4.2500
# Sample 7: x1=0.139, x2=0.292, x3=0.366, target=5.789, pred=5.531, error=0.258
#          Updated weights => w1=0.9413, w2=2.5058, w3=1.1426, bias=4.2526
# Sample 8: x1=0.456, x2=0.785, x3=0.200, target=8.068, pred=6.878, error=1.190
#          Updated weights => w1=0.9468, w2=2.5152, w3=1.1449, bias=4.2645
# Sample 9: x1=0.514, x2=0.592, x3=0.046, target=7.759, pred=6.295, error=1.465
#          Updated weights => w1=0.9543, w2=2.5238, w3=1.1456, bias=4.2791
# Epoch 18 MSE: 0.716644
#
# Epoch 19: Weights => w1 = 0.9543, w2 = 2.5238, w3 = 1.1456, bias = 4.2791
# Sample 0: x1=0.375, x2=0.951, x3=0.732, target=7.869, pred=7.875, error=-0.005
#          Updated weights => w1=0.9543, w2=2.5238, w3=1.1456, bias=4.2791
# Sample 1: x1=0.599, x2=0.156, x3=0.156, target=6.509, pred=5.423, error=1.087
#          Updated weights => w1=0.9608, w2=2.5255, w3=1.1473, bias=4.2899
# Sample 2: x1=0.058, x2=0.866, x3=0.601, target=7.114, pred=7.223, error=-0.109
#          Updated weights => w1=0.9607, w2=2.5245, w3=1.1466, bias=4.2888
# Sample 3: x1=0.708, x2=0.021, x3=0.970, target=5.508, pred=6.133, error=-0.625
#          Updated weights => w1=0.9563, w2=2.5244, w3=1.1405, bias=4.2826
# Sample 4: x1=0.832, x2=0.212, x3=0.182, target=7.120, pred=5.822, error=1.298
#          Updated weights => w1=0.9671, w2=2.5272, w3=1.1429, bias=4.2956
# Sample 5: x1=0.183, x2=0.304, x3=0.525, target=5.755, pred=5.842, error=-0.087
#          Updated weights => w1=0.9669, w2=2.5269, w3=1.1425, bias=4.2947
# Sample 6: x1=0.432, x2=0.291, x3=0.612, target=6.126, pred=6.147, error=-0.022
#          Updated weights => w1=0.9668, w2=2.5268, w3=1.1423, bias=4.2945
# Sample 7: x1=0.139, x2=0.292, x3=0.366, target=5.789, pred=5.586, error=0.203
#          Updated weights => w1=0.9671, w2=2.5274, w3=1.1431, bias=4.2965
# Sample 8: x1=0.456, x2=0.785, x3=0.200, target=8.068, pred=6.950, error=1.118
#          Updated weights => w1=0.9722, w2=2.5362, w3=1.1453, bias=4.3077
# Sample 9: x1=0.514, x2=0.592, x3=0.046, target=7.759, pred=6.363, error=1.396
#          Updated weights => w1=0.9794, w2=2.5445, w3=1.1459, bias=4.3217
# Epoch 19 MSE: 0.651535
#
# Epoch 20: Weights => w1 = 0.9794, w2 = 2.5445, w3 = 1.1459, bias = 4.3217
# Sample 0: x1=0.375, x2=0.951, x3=0.732, target=7.869, pred=7.946, error=-0.077
#          Updated weights => w1=0.9791, w2=2.5437, w3=1.1454, bias=4.3209
# Sample 1: x1=0.599, x2=0.156, x3=0.156, target=6.509, pred=5.483, error=1.027
#          Updated weights => w1=0.9853, w2=2.5453, w3=1.1470, bias=4.3312
# Sample 2: x1=0.058, x2=0.866, x3=0.601, target=7.114, pred=7.283, error=-0.169
#          Updated weights => w1=0.9852, w2=2.5439, w3=1.1460, bias=4.3295
# Sample 3: x1=0.708, x2=0.021, x3=0.970, target=5.508, pred=6.191, error=-0.683
#          Updated weights => w1=0.9803, w2=2.5437, w3=1.1393, bias=4.3226
# Sample 4: x1=0.832, x2=0.212, x3=0.182, target=7.120, pred=5.886, error=1.234
#          Updated weights => w1=0.9906, w2=2.5464, w3=1.1416, bias=4.3350
# Sample 5: x1=0.183, x2=0.304, x3=0.525, target=5.755, pred=5.890, error=-0.136
#          Updated weights => w1=0.9903, w2=2.5459, w3=1.1409, bias=4.3336
# Sample 6: x1=0.432, x2=0.291, x3=0.612, target=6.126, pred=6.201, error=-0.075
#          Updated weights => w1=0.9900, w2=2.5457, w3=1.1404, bias=4.3329
# Sample 7: x1=0.139, x2=0.292, x3=0.366, target=5.789, pred=5.632, error=0.157
#          Updated weights => w1=0.9902, w2=2.5462, w3=1.1410, bias=4.3344
# Sample 8: x1=0.456, x2=0.785, x3=0.200, target=8.068, pred=7.013, error=1.055
#          Updated weights => w1=0.9951, w2=2.5545, w3=1.1431, bias=4.3450
# Sample 9: x1=0.514, x2=0.592, x3=0.046, target=7.759, pred=6.423, error=1.336
#          Updated weights => w1=1.0019, w2=2.5624, w3=1.1437, bias=4.3583
# Epoch 20 MSE: 0.602492
#
# Epoch 21: Weights => w1 = 1.0019, w2 = 2.5624, w3 = 1.1437, bias = 4.3583
# Sample 0: x1=0.375, x2=0.951, x3=0.732, target=7.869, pred=8.007, error=-0.138
#          Updated weights => w1=1.0014, w2=2.5611, w3=1.1427, bias=4.3570
# Sample 1: x1=0.599, x2=0.156, x3=0.156, target=6.509, pred=5.534, error=0.975
#          Updated weights => w1=1.0072, w2=2.5626, w3=1.1442, bias=4.3667
# Sample 2: x1=0.058, x2=0.866, x3=0.601, target=7.114, pred=7.333, error=-0.219
#          Updated weights => w1=1.0071, w2=2.5607, w3=1.1429, bias=4.3645
# Sample 3: x1=0.708, x2=0.021, x3=0.970, target=5.508, pred=6.239, error=-0.731
#          Updated weights => w1=1.0019, w2=2.5605, w3=1.1358, bias=4.3572
# Sample 4: x1=0.832, x2=0.212, x3=0.182, target=7.120, pred=5.942, error=1.179
#          Updated weights => w1=1.0118, w2=2.5630, w3=1.1380, bias=4.3690
# Sample 5: x1=0.183, x2=0.304, x3=0.525, target=5.755, pred=5.932, error=-0.177
#          Updated weights => w1=1.0114, w2=2.5625, w3=1.1370, bias=4.3672
# Sample 6: x1=0.432, x2=0.291, x3=0.612, target=6.126, pred=6.246, error=-0.120
#          Updated weights => w1=1.0109, w2=2.5622, w3=1.1363, bias=4.3660
# Sample 7: x1=0.139, x2=0.292, x3=0.366, target=5.789, pred=5.672, error=0.117
#          Updated weights => w1=1.0111, w2=2.5625, w3=1.1367, bias=4.3672
# Sample 8: x1=0.456, x2=0.785, x3=0.200, target=8.068, pred=7.067, error=1.001
#          Updated weights => w1=1.0156, w2=2.5704, w3=1.1387, bias=4.3772
# Sample 9: x1=0.514, x2=0.592, x3=0.046, target=7.759, pred=6.475, error=1.284
#          Updated weights => w1=1.0222, w2=2.5780, w3=1.1393, bias=4.3901
# Epoch 21 MSE: 0.565085
#
# Epoch 22: Weights => w1 = 1.0222, w2 = 2.5780, w3 = 1.1393, bias = 4.3901
# Sample 0: x1=0.375, x2=0.951, x3=0.732, target=7.869, pred=8.058, error=-0.189
#          Updated weights => w1=1.0215, w2=2.5762, w3=1.1379, bias=4.3882
# Sample 1: x1=0.599, x2=0.156, x3=0.156, target=6.509, pred=5.579, error=0.930
#          Updated weights => w1=1.0271, w2=2.5776, w3=1.1394, bias=4.3975
# Sample 2: x1=0.058, x2=0.866, x3=0.601, target=7.114, pred=7.375, error=-0.261
#          Updated weights => w1=1.0269, w2=2.5754, w3=1.1378, bias=4.3949
# Sample 3: x1=0.708, x2=0.021, x3=0.970, target=5.508, pred=6.279, error=-0.771
#          Updated weights => w1=1.0215, w2=2.5752, w3=1.1304, bias=4.3872
# Sample 4: x1=0.832, x2=0.212, x3=0.182, target=7.120, pred=5.990, error=1.130
#          Updated weights => w1=1.0309, w2=2.5776, w3=1.1324, bias=4.3985
# Sample 5: x1=0.183, x2=0.304, x3=0.525, target=5.755, pred=5.966, error=-0.211
#          Updated weights => w1=1.0305, w2=2.5770, w3=1.1313, bias=4.3963
# Sample 6: x1=0.432, x2=0.291, x3=0.612, target=6.126, pred=6.284, error=-0.158
#          Updated weights => w1=1.0298, w2=2.5765, w3=1.1303, bias=4.3948
# Sample 7: x1=0.139, x2=0.292, x3=0.366, target=5.789, pred=5.705, error=0.084
#          Updated weights => w1=1.0299, w2=2.5767, w3=1.1306, bias=4.3956
# Sample 8: x1=0.456, x2=0.785, x3=0.200, target=8.068, pred=7.114, error=0.954
#          Updated weights => w1=1.0343, w2=2.5842, w3=1.1325, bias=4.4051
# Sample 9: x1=0.514, x2=0.592, x3=0.046, target=7.759, pred=6.521, error=1.239
#          Updated weights => w1=1.0407, w2=2.5916, w3=1.1331, bias=4.4175
# Epoch 22 MSE: 0.536108
#
# Epoch 23: Weights => w1 = 1.0407, w2 = 2.5916, w3 = 1.1331, bias = 4.4175
# Sample 0: x1=0.375, x2=0.951, x3=0.732, target=7.869, pred=8.101, error=-0.231
#          Updated weights => w1=1.0398, w2=2.5894, w3=1.1314, bias=4.4152
# Sample 1: x1=0.599, x2=0.156, x3=0.156, target=6.509, pred=5.618, error=0.891
#          Updated weights => w1=1.0451, w2=2.5908, w3=1.1328, bias=4.4241
# Sample 2: x1=0.058, x2=0.866, x3=0.601, target=7.114, pred=7.410, error=-0.296
#          Updated weights => w1=1.0450, w2=2.5882, w3=1.1310, bias=4.4212
# Sample 3: x1=0.708, x2=0.021, x3=0.970, target=5.508, pred=6.311, error=-0.803
#          Updated weights => w1=1.0393, w2=2.5880, w3=1.1232, bias=4.4131
# Sample 4: x1=0.832, x2=0.212, x3=0.182, target=7.120, pred=6.032, error=1.088
#          Updated weights => w1=1.0483, w2=2.5903, w3=1.1252, bias=4.4240
# Sample 5: x1=0.183, x2=0.304, x3=0.525, target=5.755, pred=5.995, error=-0.240
#          Updated weights => w1=1.0479, w2=2.5896, w3=1.1240, bias=4.4216
# Sample 6: x1=0.432, x2=0.291, x3=0.612, target=6.126, pred=6.316, error=-0.190
#          Updated weights => w1=1.0471, w2=2.5891, w3=1.1228, bias=4.4197
# Sample 7: x1=0.139, x2=0.292, x3=0.366, target=5.789, pred=5.733, error=0.056
#          Updated weights => w1=1.0471, w2=2.5892, w3=1.1230, bias=4.4203
# Sample 8: x1=0.456, x2=0.785, x3=0.200, target=8.068, pred=7.155, error=0.913
#          Updated weights => w1=1.0513, w2=2.5964, w3=1.1248, bias=4.4294
# Sample 9: x1=0.514, x2=0.592, x3=0.046, target=7.759, pred=6.560, error=1.199
#          Updated weights => w1=1.0575, w2=2.6035, w3=1.1254, bias=4.4414
# Epoch 23 MSE: 0.513244
#
# Epoch 24: Weights => w1 = 1.0575, w2 = 2.6035, w3 = 1.1254, bias = 4.4414
# Sample 0: x1=0.375, x2=0.951, x3=0.732, target=7.869, pred=8.136, error=-0.267
#          Updated weights => w1=1.0565, w2=2.6009, w3=1.1234, bias=4.4387
# Sample 1: x1=0.599, x2=0.156, x3=0.156, target=6.509, pred=5.652, error=0.857
#          Updated weights => w1=1.0616, w2=2.6023, w3=1.1248, bias=4.4473
# Sample 2: x1=0.058, x2=0.866, x3=0.601, target=7.114, pred=7.439, error=-0.326
#          Updated weights => w1=1.0614, w2=2.5995, w3=1.1228, bias=4.4440
# Sample 3: x1=0.708, x2=0.021, x3=0.970, target=5.508, pred=6.338, error=-0.830
#          Updated weights => w1=1.0555, w2=2.5993, w3=1.1148, bias=4.4357
# Sample 4: x1=0.832, x2=0.212, x3=0.182, target=7.120, pred=6.069, error=1.051
#          Updated weights => w1=1.0643, w2=2.6015, w3=1.1167, bias=4.4462
# Sample 5: x1=0.183, x2=0.304, x3=0.525, target=5.755, pred=6.019, error=-0.264
#          Updated weights => w1=1.0638, w2=2.6007, w3=1.1153, bias=4.4436
# Sample 6: x1=0.432, x2=0.291, x3=0.612, target=6.126, pred=6.343, error=-0.217
#          Updated weights => w1=1.0629, w2=2.6001, w3=1.1139, bias=4.4414
# Sample 7: x1=0.139, x2=0.292, x3=0.366, target=5.789, pred=5.757, error=0.032
#          Updated weights => w1=1.0629, w2=2.6002, w3=1.1141, bias=4.4417
# Sample 8: x1=0.456, x2=0.785, x3=0.200, target=8.068, pred=7.191, error=0.877
#          Updated weights => w1=1.0669, w2=2.6071, w3=1.1158, bias=4.4505
# Sample 9: x1=0.514, x2=0.592, x3=0.046, target=7.759, pred=6.595, error=1.164
#          Updated weights => w1=1.0729, w2=2.6140, w3=1.1164, bias=4.4621
# Epoch 24 MSE: 0.494817
#
# Epoch 25: Weights => w1 = 1.0729, w2 = 2.6140, w3 = 1.1164, bias = 4.4621
# Sample 0: x1=0.375, x2=0.951, x3=0.732, target=7.869, pred=8.166, error=-0.297
#          Updated weights => w1=1.0718, w2=2.6111, w3=1.1142, bias=4.4592
# Sample 1: x1=0.599, x2=0.156, x3=0.156, target=6.509, pred=5.682, error=0.827
#          Updated weights => w1=1.0767, w2=2.6124, w3=1.1155, bias=4.4675
# Sample 2: x1=0.058, x2=0.866, x3=0.601, target=7.114, pred=7.463, error=-0.350
#          Updated weights => w1=1.0765, w2=2.6094, w3=1.1134, bias=4.4640
# Sample 3: x1=0.708, x2=0.021, x3=0.970, target=5.508, pred=6.360, error=-0.852
#          Updated weights => w1=1.0705, w2=2.6092, w3=1.1051, bias=4.4554
# Sample 4: x1=0.832, x2=0.212, x3=0.182, target=7.120, pred=6.102, error=1.019
#          Updated weights => w1=1.0790, w2=2.6114, w3=1.1070, bias=4.4656
# Sample 5: x1=0.183, x2=0.304, x3=0.525, target=5.755, pred=6.039, error=-0.284
#          Updated weights => w1=1.0785, w2=2.6105, w3=1.1055, bias=4.4628
# Sample 6: x1=0.432, x2=0.291, x3=0.612, target=6.126, pred=6.365, error=-0.240
#          Updated weights => w1=1.0774, w2=2.6098, w3=1.1040, bias=4.4604
# Sample 7: x1=0.139, x2=0.292, x3=0.366, target=5.789, pred=5.778, error=0.011
#          Updated weights => w1=1.0774, w2=2.6099, w3=1.1040, bias=4.4605
# Sample 8: x1=0.456, x2=0.785, x3=0.200, target=8.068, pred=7.222, error=0.846
#          Updated weights => w1=1.0813, w2=2.6165, w3=1.1057, bias=4.4690
# Sample 9: x1=0.514, x2=0.592, x3=0.046, target=7.759, pred=6.626, error=1.133
#          Updated weights => w1=1.0871, w2=2.6232, w3=1.1063, bias=4.4803
# Epoch 25 MSE: 0.479615
#
# Epoch 26: Weights => w1 = 1.0871, w2 = 2.6232, w3 = 1.1063, bias = 4.4803
# Sample 0: x1=0.375, x2=0.951, x3=0.732, target=7.869, pred=8.191, error=-0.322
#          Updated weights => w1=1.0859, w2=2.6202, w3=1.1039, bias=4.4771
# Sample 1: x1=0.599, x2=0.156, x3=0.156, target=6.509, pred=5.708, error=0.801
#          Updated weights => w1=1.0907, w2=2.6214, w3=1.1052, bias=4.4851
# Sample 2: x1=0.058, x2=0.866, x3=0.601, target=7.114, pred=7.483, error=-0.370
#          Updated weights => w1=1.0905, w2=2.6182, w3=1.1029, bias=4.4814
# Sample 3: x1=0.708, x2=0.021, x3=0.970, target=5.508, pred=6.377, error=-0.869
#          Updated weights => w1=1.0843, w2=2.6180, w3=1.0945, bias=4.4727
# Sample 4: x1=0.832, x2=0.212, x3=0.182, target=7.120, pred=6.130, error=0.990
#          Updated weights => w1=1.0926, w2=2.6201, w3=1.0963, bias=4.4826
# Sample 5: x1=0.183, x2=0.304, x3=0.525, target=5.755, pred=6.055, error=-0.301
#          Updated weights => w1=1.0920, w2=2.6192, w3=1.0947, bias=4.4796
# Sample 6: x1=0.432, x2=0.291, x3=0.612, target=6.126, pred=6.384, error=-0.258
#          Updated weights => w1=1.0909, w2=2.6185, w3=1.0931, bias=4.4770
# Sample 7: x1=0.139, x2=0.292, x3=0.366, target=5.789, pred=5.795, error=-0.006
#          Updated weights => w1=1.0909, w2=2.6184, w3=1.0931, bias=4.4769
# Sample 8: x1=0.456, x2=0.785, x3=0.200, target=8.068, pred=7.249, error=0.819
#          Updated weights => w1=1.0947, w2=2.6249, w3=1.0948, bias=4.4851
# Sample 9: x1=0.514, x2=0.592, x3=0.046, target=7.759, pred=6.654, error=1.105
#          Updated weights => w1=1.1003, w2=2.6314, w3=1.0953, bias=4.4962
# Epoch 26 MSE: 0.466765
#
# Epoch 27: Weights => w1 = 1.1003, w2 = 2.6314, w3 = 1.0953, bias = 4.4962
# Sample 0: x1=0.375, x2=0.951, x3=0.732, target=7.869, pred=8.212, error=-0.343
#          Updated weights => w1=1.0991, w2=2.6282, w3=1.0928, bias=4.4928
# Sample 1: x1=0.599, x2=0.156, x3=0.156, target=6.509, pred=5.731, error=0.778
#          Updated weights => w1=1.1037, w2=2.6294, w3=1.0940, bias=4.5006
# Sample 2: x1=0.058, x2=0.866, x3=0.601, target=7.114, pred=7.500, error=-0.386
#          Updated weights => w1=1.1035, w2=2.6260, w3=1.0917, bias=4.4967
# Sample 3: x1=0.708, x2=0.021, x3=0.970, target=5.508, pred=6.391, error=-0.883
#          Updated weights => w1=1.0972, w2=2.6259, w3=1.0831, bias=4.4879
# Sample 4: x1=0.832, x2=0.212, x3=0.182, target=7.120, pred=6.156, error=0.964
#          Updated weights => w1=1.1053, w2=2.6279, w3=1.0848, bias=4.4975
# Sample 5: x1=0.183, x2=0.304, x3=0.525, target=5.755, pred=6.069, error=-0.314
#          Updated weights => w1=1.1047, w2=2.6270, w3=1.0832, bias=4.4944
# Sample 6: x1=0.432, x2=0.291, x3=0.612, target=6.126, pred=6.399, error=-0.274
#          Updated weights => w1=1.1035, w2=2.6262, w3=1.0815, bias=4.4916
# Sample 7: x1=0.139, x2=0.292, x3=0.366, target=5.789, pred=5.809, error=-0.020
#          Updated weights => w1=1.1035, w2=2.6261, w3=1.0815, bias=4.4914
# Sample 8: x1=0.456, x2=0.785, x3=0.200, target=8.068, pred=7.273, error=0.795
#          Updated weights => w1=1.1071, w2=2.6323, w3=1.0830, bias=4.4994
# Sample 9: x1=0.514, x2=0.592, x3=0.046, target=7.759, pred=6.678, error=1.081
#          Updated weights => w1=1.1127, w2=2.6387, w3=1.0835, bias=4.5102
# Epoch 27 MSE: 0.455634
#
# Epoch 28: Weights => w1 = 1.1127, w2 = 2.6387, w3 = 1.0835, bias = 4.5102
# Sample 0: x1=0.375, x2=0.951, x3=0.732, target=7.869, pred=8.229, error=-0.360
#          Updated weights => w1=1.1113, w2=2.6353, w3=1.0809, bias=4.5066
# Sample 1: x1=0.599, x2=0.156, x3=0.156, target=6.509, pred=5.752, error=0.758
#          Updated weights => w1=1.1159, w2=2.6365, w3=1.0821, bias=4.5142
# Sample 2: x1=0.058, x2=0.866, x3=0.601, target=7.114, pred=7.513, error=-0.400
#          Updated weights => w1=1.1156, w2=2.6330, w3=1.0797, bias=4.5102
# Sample 3: x1=0.708, x2=0.021, x3=0.970, target=5.508, pred=6.402, error=-0.894
#          Updated weights => w1=1.1093, w2=2.6329, w3=1.0710, bias=4.5012
# Sample 4: x1=0.832, x2=0.212, x3=0.182, target=7.120, pred=6.178, error=0.942
#          Updated weights => w1=1.1171, w2=2.6349, w3=1.0727, bias=4.5107
# Sample 5: x1=0.183, x2=0.304, x3=0.525, target=5.755, pred=6.080, error=-0.325
#          Updated weights => w1=1.1165, w2=2.6339, w3=1.0710, bias=4.5074
# Sample 6: x1=0.432, x2=0.291, x3=0.612, target=6.126, pred=6.412, error=-0.286
#          Updated weights => w1=1.1153, w2=2.6330, w3=1.0693, bias=4.5045
# Sample 7: x1=0.139, x2=0.292, x3=0.366, target=5.789, pred=5.821, error=-0.032
#          Updated weights => w1=1.1153, w2=2.6329, w3=1.0692, bias=4.5042
# Sample 8: x1=0.456, x2=0.785, x3=0.200, target=8.068, pred=7.294, error=0.774
#          Updated weights => w1=1.1188, w2=2.6390, w3=1.0707, bias=4.5120
# Sample 9: x1=0.514, x2=0.592, x3=0.046, target=7.759, pred=6.700, error=1.059
#          Updated weights => w1=1.1242, w2=2.6453, w3=1.0712, bias=4.5225
# Epoch 28 MSE: 0.445767
#
# Epoch 29: Weights => w1 = 1.1242, w2 = 2.6453, w3 = 1.0712, bias = 4.5225
# Sample 0: x1=0.375, x2=0.951, x3=0.732, target=7.869, pred=8.243, error=-0.373
#          Updated weights => w1=1.1228, w2=2.6417, w3=1.0685, bias=4.5188
# Sample 1: x1=0.599, x2=0.156, x3=0.156, target=6.509, pred=5.770, error=0.740
#          Updated weights => w1=1.1273, w2=2.6429, w3=1.0696, bias=4.5262
# Sample 2: x1=0.058, x2=0.866, x3=0.601, target=7.114, pred=7.524, error=-0.410
#          Updated weights => w1=1.1270, w2=2.6393, w3=1.0672, bias=4.5221
# Sample 3: x1=0.708, x2=0.021, x3=0.970, target=5.508, pred=6.409, error=-0.902
#          Updated weights => w1=1.1206, w2=2.6392, w3=1.0584, bias=4.5131
# Sample 4: x1=0.832, x2=0.212, x3=0.182, target=7.120, pred=6.199, error=0.921
#          Updated weights => w1=1.1283, w2=2.6411, w3=1.0601, bias=4.5223
# Sample 5: x1=0.183, x2=0.304, x3=0.525, target=5.755, pred=6.089, error=-0.334
#          Updated weights => w1=1.1277, w2=2.6401, w3=1.0583, bias=4.5190
# Sample 6: x1=0.432, x2=0.291, x3=0.612, target=6.126, pred=6.422, error=-0.297
#          Updated weights => w1=1.1264, w2=2.6392, w3=1.0565, bias=4.5160
# Sample 7: x1=0.139, x2=0.292, x3=0.366, target=5.789, pred=5.831, error=-0.042
#          Updated weights => w1=1.1264, w2=2.6391, w3=1.0564, bias=4.5156
# Sample 8: x1=0.456, x2=0.785, x3=0.200, target=8.068, pred=7.312, error=0.756
#          Updated weights => w1=1.1298, w2=2.6450, w3=1.0579, bias=4.5231
# Sample 9: x1=0.514, x2=0.592, x3=0.046, target=7.759, pred=6.720, error=1.039
#          Updated weights => w1=1.1351, w2=2.6512, w3=1.0583, bias=4.5335
# Epoch 29 MSE: 0.436833
#
# Epoch 30: Weights => w1 = 1.1351, w2 = 2.6512, w3 = 1.0583, bias = 4.5335
# Sample 0: x1=0.375, x2=0.951, x3=0.732, target=7.869, pred=8.254, error=-0.385
#          Updated weights => w1=1.1337, w2=2.6475, w3=1.0555, bias=4.5297
# Sample 1: x1=0.599, x2=0.156, x3=0.156, target=6.509, pred=5.786, error=0.723
#          Updated weights => w1=1.1380, w2=2.6487, w3=1.0567, bias=4.5369
# Sample 2: x1=0.058, x2=0.866, x3=0.601, target=7.114, pred=7.532, error=-0.419
#          Updated weights => w1=1.1378, w2=2.6450, w3=1.0541, bias=4.5327
# Sample 3: x1=0.708, x2=0.021, x3=0.970, target=5.508, pred=6.415, error=-0.907
#          Updated weights => w1=1.1314, w2=2.6449, w3=1.0453, bias=4.5236
# Sample 4: x1=0.832, x2=0.212, x3=0.182, target=7.120, pred=6.217, error=0.903
#          Updated weights => w1=1.1389, w2=2.6468, w3=1.0470, bias=4.5327
# Sample 5: x1=0.183, x2=0.304, x3=0.525, target=5.755, pred=6.096, error=-0.341
#          Updated weights => w1=1.1383, w2=2.6457, w3=1.0452, bias=4.5293
# Sample 6: x1=0.432, x2=0.291, x3=0.612, target=6.126, pred=6.431, error=-0.305
#          Updated weights => w1=1.1369, w2=2.6448, w3=1.0433, bias=4.5262
# Sample 7: x1=0.139, x2=0.292, x3=0.366, target=5.789, pred=5.840, error=-0.051
# ...
#          Updated weights => w1=1.5086, w2=2.7855, w3=0.2832, bias=4.7267
# Sample 1: x1=0.599, x2=0.156, x3=0.156, target=6.509, pred=6.109, error=0.401
#          Updated weights => w1=1.5110, w2=2.7862, w3=0.2838, bias=4.7307
# Sample 2: x1=0.058, x2=0.866, x3=0.601, target=7.114, pred=7.402, error=-0.289
#          Updated weights => w1=1.5108, w2=2.7837, w3=0.2821, bias=4.7279
# Sample 3: x1=0.708, x2=0.021, x3=0.970, target=5.508, pred=6.129, error=-0.621
#          Updated weights => w1=1.5064, w2=2.7835, w3=0.2760, bias=4.7217
# Sample 4: x1=0.832, x2=0.212, x3=0.182, target=7.120, pred=6.617, error=0.503
#          Updated weights => w1=1.5106, w2=2.7846, w3=0.2770, bias=4.7267
# Sample 5: x1=0.183, x2=0.304, x3=0.525, target=5.755, pred=5.996, error=-0.241
#          Updated weights => w1=1.5102, w2=2.7839, w3=0.2757, bias=4.7243
# Sample 6: x1=0.432, x2=0.291, x3=0.612, target=6.126, pred=6.356, error=-0.230
#          Updated weights => w1=1.5092, w2=2.7832, w3=0.2743, bias=4.7220
# Sample 7: x1=0.139, x2=0.292, x3=0.366, target=5.789, pred=5.846, error=-0.057
#          Updated weights => w1=1.5091, w2=2.7830, w3=0.2741, bias=4.7214
# Sample 8: x1=0.456, x2=0.785, x3=0.200, target=8.068, pred=7.650, error=0.418
#          Updated weights => w1=1.5110, w2=2.7863, w3=0.2749, bias=4.7256
# Sample 9: x1=0.514, x2=0.592, x3=0.046, target=7.759, pred=7.166, error=0.593
#          Updated weights => w1=1.5141, w2=2.7898, w3=0.2752, bias=4.7315
# Epoch 91 MSE: 0.160533
#
# Epoch 92: Weights => w1 = 1.5141, w2 = 2.7898, w3 = 0.2752, bias = 4.7315
# Sample 0: x1=0.375, x2=0.951, x3=0.732, target=7.869, pred=8.152, error=-0.283
#          Updated weights => w1=1.5130, w2=2.7871, w3=0.2731, bias=4.7287
# Sample 1: x1=0.599, x2=0.156, x3=0.156, target=6.509, pred=6.112, error=0.397
#          Updated weights => w1=1.5154, w2=2.7878, w3=0.2737, bias=4.7327
# Sample 2: x1=0.058, x2=0.866, x3=0.601, target=7.114, pred=7.400, error=-0.286
#          Updated weights => w1=1.5152, w2=2.7853, w3=0.2720, bias=4.7298
# Sample 3: x1=0.708, x2=0.021, x3=0.970, target=5.508, pred=6.124, error=-0.616
#          Updated weights => w1=1.5109, w2=2.7851, w3=0.2660, bias=4.7236
# Sample 4: x1=0.832, x2=0.212, x3=0.182, target=7.120, pred=6.621, error=0.499
#          Updated weights => w1=1.5150, w2=2.7862, w3=0.2669, bias=4.7286
# Sample 5: x1=0.183, x2=0.304, x3=0.525, target=5.755, pred=5.994, error=-0.239
#          Updated weights => w1=1.5146, w2=2.7855, w3=0.2657, bias=4.7262
# Sample 6: x1=0.432, x2=0.291, x3=0.612, target=6.126, pred=6.354, error=-0.228
#          Updated weights => w1=1.5136, w2=2.7848, w3=0.2643, bias=4.7239
# Sample 7: x1=0.139, x2=0.292, x3=0.366, target=5.789, pred=5.845, error=-0.056
#          Updated weights => w1=1.5135, w2=2.7846, w3=0.2641, bias=4.7234
# Sample 8: x1=0.456, x2=0.785, x3=0.200, target=8.068, pred=7.653, error=0.415
#          Updated weights => w1=1.5154, w2=2.7879, w3=0.2649, bias=4.7275
# Sample 9: x1=0.514, x2=0.592, x3=0.046, target=7.759, pred=7.171, error=0.589
#          Updated weights => w1=1.5184, w2=2.7914, w3=0.2652, bias=4.7334
# Epoch 92 MSE: 0.157987
#
# Epoch 93: Weights => w1 = 1.5184, w2 = 2.7914, w3 = 0.2652, bias = 4.7334
# Sample 0: x1=0.375, x2=0.951, x3=0.732, target=7.869, pred=8.150, error=-0.281
#          Updated weights => w1=1.5174, w2=2.7887, w3=0.2631, bias=4.7306
# Sample 1: x1=0.599, x2=0.156, x3=0.156, target=6.509, pred=6.115, error=0.394
#          Updated weights => w1=1.5197, w2=2.7893, w3=0.2637, bias=4.7346
# Sample 2: x1=0.058, x2=0.866, x3=0.601, target=7.114, pred=7.397, error=-0.284
#          Updated weights => w1=1.5196, w2=2.7869, w3=0.2620, bias=4.7317
# Sample 3: x1=0.708, x2=0.021, x3=0.970, target=5.508, pred=6.119, error=-0.611
#          Updated weights => w1=1.5152, w2=2.7868, w3=0.2561, bias=4.7256
# Sample 4: x1=0.832, x2=0.212, x3=0.182, target=7.120, pred=6.625, error=0.495
#          Updated weights => w1=1.5194, w2=2.7878, w3=0.2570, bias=4.7306
# Sample 5: x1=0.183, x2=0.304, x3=0.525, target=5.755, pred=5.992, error=-0.237
#          Updated weights => w1=1.5189, w2=2.7871, w3=0.2558, bias=4.7282
# Sample 6: x1=0.432, x2=0.291, x3=0.612, target=6.126, pred=6.352, error=-0.227
#          Updated weights => w1=1.5180, w2=2.7864, w3=0.2544, bias=4.7259
# Sample 7: x1=0.139, x2=0.292, x3=0.366, target=5.789, pred=5.845, error=-0.056
#          Updated weights => w1=1.5179, w2=2.7863, w3=0.2542, bias=4.7254
# Sample 8: x1=0.456, x2=0.785, x3=0.200, target=8.068, pred=7.656, error=0.412
#          Updated weights => w1=1.5198, w2=2.7895, w3=0.2550, bias=4.7295
# Sample 9: x1=0.514, x2=0.592, x3=0.046, target=7.759, pred=7.175, error=0.584
#          Updated weights => w1=1.5228, w2=2.7930, w3=0.2553, bias=4.7353
# Epoch 93 MSE: 0.155482
#
# Epoch 94: Weights => w1 = 1.5228, w2 = 2.7930, w3 = 0.2553, bias = 4.7353
# Sample 0: x1=0.375, x2=0.951, x3=0.732, target=7.869, pred=8.148, error=-0.279
#          Updated weights => w1=1.5217, w2=2.7903, w3=0.2532, bias=4.7325
# Sample 1: x1=0.599, x2=0.156, x3=0.156, target=6.509, pred=6.118, error=0.391
#          Updated weights => w1=1.5241, w2=2.7909, w3=0.2538, bias=4.7364
# Sample 2: x1=0.058, x2=0.866, x3=0.601, target=7.114, pred=7.395, error=-0.281
#          Updated weights => w1=1.5239, w2=2.7885, w3=0.2521, bias=4.7336
# Sample 3: x1=0.708, x2=0.021, x3=0.970, target=5.508, pred=6.115, error=-0.607
#          Updated weights => w1=1.5196, w2=2.7884, w3=0.2463, bias=4.7276
# Sample 4: x1=0.832, x2=0.212, x3=0.182, target=7.120, pred=6.629, error=0.491
#          Updated weights => w1=1.5237, w2=2.7894, w3=0.2472, bias=4.7325
# Sample 5: x1=0.183, x2=0.304, x3=0.525, target=5.755, pred=5.990, error=-0.235
#          Updated weights => w1=1.5232, w2=2.7887, w3=0.2459, bias=4.7301
# Sample 6: x1=0.432, x2=0.291, x3=0.612, target=6.126, pred=6.351, error=-0.225
#          Updated weights => w1=1.5223, w2=2.7880, w3=0.2445, bias=4.7279
# Sample 7: x1=0.139, x2=0.292, x3=0.366, target=5.789, pred=5.844, error=-0.055
#          Updated weights => w1=1.5222, w2=2.7879, w3=0.2443, bias=4.7273
# Sample 8: x1=0.456, x2=0.785, x3=0.200, target=8.068, pred=7.659, error=0.409
#          Updated weights => w1=1.5241, w2=2.7911, w3=0.2452, bias=4.7314
# Sample 9: x1=0.514, x2=0.592, x3=0.046, target=7.759, pred=7.180, error=0.579
#          Updated weights => w1=1.5270, w2=2.7945, w3=0.2454, bias=4.7372
# Epoch 94 MSE: 0.153017
#
# Epoch 95: Weights => w1 = 1.5270, w2 = 2.7945, w3 = 0.2454, bias = 4.7372
# Sample 0: x1=0.375, x2=0.951, x3=0.732, target=7.869, pred=8.146, error=-0.276
#          Updated weights => w1=1.5260, w2=2.7919, w3=0.2434, bias=4.7344
# Sample 1: x1=0.599, x2=0.156, x3=0.156, target=6.509, pred=6.122, error=0.388
#          Updated weights => w1=1.5283, w2=2.7925, w3=0.2440, bias=4.7383
# Sample 2: x1=0.058, x2=0.866, x3=0.601, target=7.114, pred=7.393, error=-0.279
#          Updated weights => w1=1.5282, w2=2.7901, w3=0.2423, bias=4.7355
# Sample 3: x1=0.708, x2=0.021, x3=0.970, target=5.508, pred=6.110, error=-0.602
#          Updated weights => w1=1.5239, w2=2.7899, w3=0.2365, bias=4.7295
# Sample 4: x1=0.832, x2=0.212, x3=0.182, target=7.120, pred=6.633, error=0.487
#          Updated weights => w1=1.5280, w2=2.7910, w3=0.2374, bias=4.7344
# Sample 5: x1=0.183, x2=0.304, x3=0.525, target=5.755, pred=5.988, error=-0.234
#          Updated weights => w1=1.5275, w2=2.7903, w3=0.2362, bias=4.7320
# Sample 6: x1=0.432, x2=0.291, x3=0.612, target=6.126, pred=6.349, error=-0.223
#          Updated weights => w1=1.5266, w2=2.7896, w3=0.2348, bias=4.7298
# Sample 7: x1=0.139, x2=0.292, x3=0.366, target=5.789, pred=5.844, error=-0.055
#          Updated weights => w1=1.5265, w2=2.7895, w3=0.2346, bias=4.7292
# Sample 8: x1=0.456, x2=0.785, x3=0.200, target=8.068, pred=7.662, error=0.406
#          Updated weights => w1=1.5283, w2=2.7926, w3=0.2354, bias=4.7333
# Sample 9: x1=0.514, x2=0.592, x3=0.046, target=7.759, pred=7.185, error=0.575
#          Updated weights => w1=1.5313, w2=2.7960, w3=0.2357, bias=4.7390
# Epoch 95 MSE: 0.150590
#
# Epoch 96: Weights => w1 = 1.5313, w2 = 2.7960, w3 = 0.2357, bias = 4.7390
# Sample 0: x1=0.375, x2=0.951, x3=0.732, target=7.869, pred=8.143, error=-0.274
#          Updated weights => w1=1.5303, w2=2.7934, w3=0.2337, bias=4.7363
# Sample 1: x1=0.599, x2=0.156, x3=0.156, target=6.509, pred=6.125, error=0.385
#          Updated weights => w1=1.5326, w2=2.7940, w3=0.2343, bias=4.7402
# Sample 2: x1=0.058, x2=0.866, x3=0.601, target=7.114, pred=7.390, error=-0.277
#          Updated weights => w1=1.5324, w2=2.7916, w3=0.2326, bias=4.7374
# Sample 3: x1=0.708, x2=0.021, x3=0.970, target=5.508, pred=6.105, error=-0.598
#          Updated weights => w1=1.5282, w2=2.7915, w3=0.2268, bias=4.7314
# Sample 4: x1=0.832, x2=0.212, x3=0.182, target=7.120, pred=6.638, error=0.483
#          Updated weights => w1=1.5322, w2=2.7925, w3=0.2277, bias=4.7362
# Sample 5: x1=0.183, x2=0.304, x3=0.525, target=5.755, pred=5.986, error=-0.232
#          Updated weights => w1=1.5318, w2=2.7918, w3=0.2265, bias=4.7339
# Sample 6: x1=0.432, x2=0.291, x3=0.612, target=6.126, pred=6.347, error=-0.221
#          Updated weights => w1=1.5308, w2=2.7912, w3=0.2251, bias=4.7317
# Sample 7: x1=0.139, x2=0.292, x3=0.366, target=5.789, pred=5.843, error=-0.054
#          Updated weights => w1=1.5307, w2=2.7910, w3=0.2249, bias=4.7312
# Sample 8: x1=0.456, x2=0.785, x3=0.200, target=8.068, pred=7.666, error=0.402
#          Updated weights => w1=1.5326, w2=2.7942, w3=0.2257, bias=4.7352
# Sample 9: x1=0.514, x2=0.592, x3=0.046, target=7.759, pred=7.189, error=0.570
#          Updated weights => w1=1.5355, w2=2.7976, w3=0.2260, bias=4.7409
# Epoch 96 MSE: 0.148202
#
# Epoch 97: Weights => w1 = 1.5355, w2 = 2.7976, w3 = 0.2260, bias = 4.7409
# Sample 0: x1=0.375, x2=0.951, x3=0.732, target=7.869, pred=8.141, error=-0.272
#          Updated weights => w1=1.5345, w2=2.7950, w3=0.2240, bias=4.7382
# Sample 1: x1=0.599, x2=0.156, x3=0.156, target=6.509, pred=6.128, error=0.382
#          Updated weights => w1=1.5368, w2=2.7956, w3=0.2246, bias=4.7420
# Sample 2: x1=0.058, x2=0.866, x3=0.601, target=7.114, pred=7.388, error=-0.274
#          Updated weights => w1=1.5366, w2=2.7932, w3=0.2229, bias=4.7392
# Sample 3: x1=0.708, x2=0.021, x3=0.970, target=5.508, pred=6.101, error=-0.593
#          Updated weights => w1=1.5324, w2=2.7931, w3=0.2172, bias=4.7333
# Sample 4: x1=0.832, x2=0.212, x3=0.182, target=7.120, pred=6.642, error=0.479
#          Updated weights => w1=1.5364, w2=2.7941, w3=0.2181, bias=4.7381
# Sample 5: x1=0.183, x2=0.304, x3=0.525, target=5.755, pred=5.984, error=-0.230
#          Updated weights => w1=1.5360, w2=2.7934, w3=0.2168, bias=4.7358
# Sample 6: x1=0.432, x2=0.291, x3=0.612, target=6.126, pred=6.345, error=-0.220
#          Updated weights => w1=1.5350, w2=2.7928, w3=0.2155, bias=4.7336
# Sample 7: x1=0.139, x2=0.292, x3=0.366, target=5.789, pred=5.843, error=-0.054
#          Updated weights => w1=1.5349, w2=2.7926, w3=0.2153, bias=4.7331
# Sample 8: x1=0.456, x2=0.785, x3=0.200, target=8.068, pred=7.669, error=0.399
#          Updated weights => w1=1.5368, w2=2.7957, w3=0.2161, bias=4.7371
# Sample 9: x1=0.514, x2=0.592, x3=0.046, target=7.759, pred=7.194, error=0.566
#          Updated weights => w1=1.5397, w2=2.7991, w3=0.2164, bias=4.7427
# Epoch 97 MSE: 0.145853
#
# Epoch 98: Weights => w1 = 1.5397, w2 = 2.7991, w3 = 0.2164, bias = 4.7427
# Sample 0: x1=0.375, x2=0.951, x3=0.732, target=7.869, pred=8.139, error=-0.270
#          Updated weights => w1=1.5387, w2=2.7965, w3=0.2144, bias=4.7400
# Sample 1: x1=0.599, x2=0.156, x3=0.156, target=6.509, pred=6.131, error=0.378
#          Updated weights => w1=1.5409, w2=2.7971, w3=0.2150, bias=4.7438
# Sample 2: x1=0.058, x2=0.866, x3=0.601, target=7.114, pred=7.385, error=-0.272
#          Updated weights => w1=1.5408, w2=2.7948, w3=0.2133, bias=4.7411
# Sample 3: x1=0.708, x2=0.021, x3=0.970, target=5.508, pred=6.097, error=-0.589
#          Updated weights => w1=1.5366, w2=2.7946, w3=0.2076, bias=4.7352
# Sample 4: x1=0.832, x2=0.212, x3=0.182, target=7.120, pred=6.646, error=0.475
#          Updated weights => w1=1.5406, w2=2.7957, w3=0.2085, bias=4.7400
# Sample 5: x1=0.183, x2=0.304, x3=0.525, target=5.755, pred=5.982, error=-0.228
#          Updated weights => w1=1.5401, w2=2.7950, w3=0.2073, bias=4.7377
# Sample 6: x1=0.432, x2=0.291, x3=0.612, target=6.126, pred=6.344, error=-0.218
#          Updated weights => w1=1.5392, w2=2.7943, w3=0.2060, bias=4.7355
# Sample 7: x1=0.139, x2=0.292, x3=0.366, target=5.789, pred=5.842, error=-0.053
#          Updated weights => w1=1.5391, w2=2.7942, w3=0.2058, bias=4.7350
# Sample 8: x1=0.456, x2=0.785, x3=0.200, target=8.068, pred=7.672, error=0.396
#          Updated weights => w1=1.5409, w2=2.7973, w3=0.2066, bias=4.7389
# Sample 9: x1=0.514, x2=0.592, x3=0.046, target=7.759, pred=7.198, error=0.561
#          Updated weights => w1=1.5438, w2=2.8006, w3=0.2068, bias=4.7445
# Epoch 98 MSE: 0.143540
#
# Epoch 99: Weights => w1 = 1.5438, w2 = 2.8006, w3 = 0.2068, bias = 4.7445
# Sample 0: x1=0.375, x2=0.951, x3=0.732, target=7.869, pred=8.137, error=-0.268
#          Updated weights => w1=1.5428, w2=2.7981, w3=0.2049, bias=4.7419
# Sample 1: x1=0.599, x2=0.156, x3=0.156, target=6.509, pred=6.134, error=0.375
#          Updated weights => w1=1.5451, w2=2.7986, w3=0.2055, bias=4.7456
# Sample 2: x1=0.058, x2=0.866, x3=0.601, target=7.114, pred=7.383, error=-0.269
#          Updated weights => w1=1.5449, w2=2.7963, w3=0.2038, bias=4.7429
# Sample 3: x1=0.708, x2=0.021, x3=0.970, target=5.508, pred=6.092, error=-0.584
#          Updated weights => w1=1.5408, w2=2.7962, w3=0.1982, bias=4.7371
# Sample 4: x1=0.832, x2=0.212, x3=0.182, target=7.120, pred=6.649, error=0.471
#          Updated weights => w1=1.5447, w2=2.7972, w3=0.1990, bias=4.7418
# Sample 5: x1=0.183, x2=0.304, x3=0.525, target=5.755, pred=5.981, error=-0.226
#          Updated weights => w1=1.5443, w2=2.7965, w3=0.1978, bias=4.7395
# Sample 6: x1=0.432, x2=0.291, x3=0.612, target=6.126, pred=6.342, error=-0.216
#          Updated weights => w1=1.5433, w2=2.7959, w3=0.1965, bias=4.7374
# Sample 7: x1=0.139, x2=0.292, x3=0.366, target=5.789, pred=5.841, error=-0.052
#          Updated weights => w1=1.5433, w2=2.7957, w3=0.1963, bias=4.7368
# Sample 8: x1=0.456, x2=0.785, x3=0.200, target=8.068, pred=7.675, error=0.393
#          Updated weights => w1=1.5451, w2=2.7988, w3=0.1971, bias=4.7408
# Sample 9: x1=0.514, x2=0.592, x3=0.046, target=7.759, pred=7.203, error=0.557
#          Updated weights => w1=1.5479, w2=2.8021, w3=0.1974, bias=4.7463
# Epoch 99 MSE: 0.141264
#
# Epoch 100: Weights => w1 = 1.5479, w2 = 2.8021, w3 = 0.1974, bias = 4.7463
# Sample 0: x1=0.375, x2=0.951, x3=0.732, target=7.869, pred=8.135, error=-0.265
#          Updated weights => w1=1.5469, w2=2.7996, w3=0.1954, bias=4.7437
# Sample 1: x1=0.599, x2=0.156, x3=0.156, target=6.509, pred=6.137, error=0.372
#          Updated weights => w1=1.5492, w2=2.8002, w3=0.1960, bias=4.7474
# Sample 2: x1=0.058, x2=0.866, x3=0.601, target=7.114, pred=7.381, error=-0.267
#          Updated weights => w1=1.5490, w2=2.7979, w3=0.1944, bias=4.7447
# Sample 3: x1=0.708, x2=0.021, x3=0.970, target=5.508, pred=6.088, error=-0.580
#          Updated weights => w1=1.5449, w2=2.7977, w3=0.1888, bias=4.7389
# Sample 4: x1=0.832, x2=0.212, x3=0.182, target=7.120, pred=6.653, error=0.467
#          Updated weights => w1=1.5488, w2=2.7987, w3=0.1896, bias=4.7436
# Sample 5: x1=0.183, x2=0.304, x3=0.525, target=5.755, pred=5.979, error=-0.224
#          Updated weights => w1=1.5484, w2=2.7980, w3=0.1885, bias=4.7414
# Sample 6: x1=0.432, x2=0.291, x3=0.612, target=6.126, pred=6.340, error=-0.215
#          Updated weights => w1=1.5474, w2=2.7974, w3=0.1871, bias=4.7392
# Sample 7: x1=0.139, x2=0.292, x3=0.366, target=5.789, pred=5.841, error=-0.052
#          Updated weights => w1=1.5474, w2=2.7973, w3=0.1870, bias=4.7387
# Sample 8: x1=0.456, x2=0.785, x3=0.200, target=8.068, pred=7.678, error=0.390
#          Updated weights => w1=1.5492, w2=2.8003, w3=0.1877, bias=4.7426
# Sample 9: x1=0.514, x2=0.592, x3=0.046, target=7.759, pred=7.207, error=0.552
#          Updated weights => w1=1.5520, w2=2.8036, w3=0.1880, bias=4.7481
# Epoch 100 MSE: 0.139024

# %%
print(f"\nFinal weights: w1 = {w1:.4f}, w2 = {w2:.4f}, w3 = {w3:.4f}, bias = {b:.4f}")
# Out:
# Final weights: w1 = 1.5520, w2 = 2.8036, w3 = 0.1880, bias = 4.7481
